# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\Varsha\Desktop\dataset1.xlsx')
df.head() # just seeing that data was imported properly by outputing first 5 cells
# Out:
#   month  year  AverageTemperature
# 0   jan  2011               0.161
# 1   feb  2011               2.860
# 2   mar  2011               4.990
# 3   apr  2011               6.998
# 4   may  2011              11.545

# %%
df.shape
# Out:
# (132, 3)

# %%
df.columns
# Out:
# Index(['month', 'year', 'AverageTemperature'], dtype='object')

# %%
major_ticks = np.arange(2011, 2022, 1)                                              
minor_ticks = np.arange(1, 13 , 1)

fig = plt.figure(figsize = (6,5)) 
ax = fig.add_subplot(1,1,1) 
s = ax.scatter('month', 'year', c = 'AverageTemperature',data = df, cmap = 'Blues_r', marker = 's',s = 190)
ax.axis([df['month'].min()-10, df['month'].max()+10, df['year'].min()-10, df['year'].max()+10])

ax.set_xticks(major_ticks)                                                       
ax.set_xticks(minor_ticks, minor=True)                                           
ax.set_yticks(major_ticks)                                                                                                                                                      
ax.grid(which='both', alpha = 0.3)                                                                                                           
ax.grid(which='major', alpha=0.3) 
ax.set_xlabel('month', fontsize=10);
ax.set_ylabel('year', fontsize=10);
ax.set_title('AverageTemperature', size = 15)

# http://stackoverflow.com/questions/13943217/how-to-add-colorbars-to-scatterplots-created-like-this
cbar = plt.colorbar(mappable = s,ax = ax)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 7>()
#       5 ax = fig.add_subplot(1,1,1)
#       6 s = ax.scatter('month', 'year', c = 'AverageTemperature',data = df, cmap = 'Blues_r', marker = 's',s = 190)
# ----> 7 ax.axis([df['month'].min()-10, df['month'].max()+10, df['year'].min()-10, df['year'].max()+10])
#       9 ax.set_xticks(major_ticks)
#      10 ax.set_xticks(minor_ticks, minor=True)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
import numpy as np;
import seaborn as sns;

# %%
df.pivot('month', 'year','AverageTemperature').head()
# Out:
# year     2011    2012    2013    2014    2015    2016    2017    2018    2019  \
# month
# apr     6.998   8.332   4.246   4.568   3.798   6.840   7.028   5.292   5.723
# aug    15.134  15.328  14.669  14.370  15.874  16.913  16.565  17.196  15.032
# dec     0.926   2.246   2.927  -1.635   3.723  -1.493   0.987  -3.987   0.804
# feb     2.860   1.995  -2.057  -1.237  -1.792   2.987  -0.382   0.972   1.580
# jan     0.161   2.409  -1.608   2.621  -1.798   3.376  -0.135   2.069   0.241
#
# year     2020    2021
# month
# apr     3.247   7.008
# aug    15.301  16.454
# dec     3.805   2.340
# feb    -6.281   0.038
# jan    -2.852   3.233

# %%
plt.figure(figsize=(9,9))
pivot_table = df.pivot('month', 'year','AverageTemperature')
plt.xlabel('year', size = 15)
plt.ylabel('month', size = 15)
plt.title('AverageTemperature', size = 15)
sns.heatmap(pivot_table, annot=True, fmt=".1f", linewidths=.5, square = True, cmap = 'Blues_r');
